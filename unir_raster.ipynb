# %%
import xarray as xr
import geopandas as gpd
import pandas as pd
import numpy as np
import rasterio as rio
from rasterio.features import geometry_mask
from rasterio.transform import from_bounds
from rasterio.warp import reproject, Resampling
import os
import glob
import rioxarray as rxr
from rasterstats import zonal_stats
from shapely.geometry import mapping
from shapely.geometry import Polygon
from osgeo import ogr

# %%
# Ruta a la carpeta que contiene los archivos raster
raster_folder = "D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps"

# %%
# Obtener una lista de todos los archivos .nc en la carpeta
raster_files = glob.glob(f"{raster_folder}/*.nc")

# %%
raster_files
# Out:
# ['D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_abaca.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_agave.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_alfalfa.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_almond.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_aniseetc.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_apple.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_apricot.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_areca.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_artichoke.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_asparagus.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_avocado.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_bambara.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_banana.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_barley.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_bean.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_beetfor.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_berrynes.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_blueberry.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_brazil.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_broadbean.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_buckwheat.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_cabbage.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_cabbagefor.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_canaryseed.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_carob.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_carrot.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_carrotfor.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_cashew.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_cashewapple.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_cassava.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_castor.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_cauliflower.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_cerealnes.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_cherry.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_chestnut.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_chickpea.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_chicory.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_chilleetc.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_cinnamon.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_citrusnes.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_clove.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_clover.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_cocoa.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_coconut.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_coffee.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_cotton.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_cowpea.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_cranberry.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_cucumberetc.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_currant.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_date.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_eggplant.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_fibrenes.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_fig.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_flax.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_fonio.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_fornes.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_fruitnes.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_garlic.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_ginger.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_gooseberry.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_grape.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_grapefruitetc.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_grassnes.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_greenbean.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_greenbroadbean.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_greencorn.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_greenonion.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_greenpea.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_groundnut.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_hazelnut.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_hemp.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_hempseed.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_hop.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_jute.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_jutelikefiber.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_kapokfiber.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_kapokseed.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_karite.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_kiwi.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_kolanut.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_legumenes.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_lemonlime.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_lentil.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_lettuce.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_linseed.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_lupin.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_maize.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_maizefor.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_mango.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_mate.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_melonetc.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_melonseed.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_millet.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_mixedgrain.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_mixedgrass.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_mushroom.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_mustard.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_nutmeg.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_nutnes.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_oats.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_oilpalm.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_oilseedfor.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_oilseednes.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_okra.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_olive.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_onion.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_orange.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_papaya.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_pea.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_peachetc.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_pear.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_pepper.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_peppermint.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_persimmon.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_pigeonpea.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_pimento.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_pineapple.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_pistachio.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_plantain.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_plum.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_popcorn.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_poppy.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_potato.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_pulsenes.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_pumpkinetc.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_pyrethrum.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_quince.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_quinoa.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_ramie.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_rapeseed.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_rasberry.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_rice.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_rootnes.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_rubber.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_rye.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_ryefor.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_safflower.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_sesame.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_sisal.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_sorghum.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_sorghumfor.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_sourcherry.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_soybean.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_spicenes.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_spinach.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_stonefruitnes.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_strawberry.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_stringbean.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_sugarbeet.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_sugarcane.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_sugarnes.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_sunflower.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_swedefor.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_sweetpotato.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_tangetc.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_taro.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_tea.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_tobacco.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_tomato.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_triticale.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_tropicalnes.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_tung.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_turnipfor.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_vanilla.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_vegetablenes.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_vegfor.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_vetch.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_walnut.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_watermelon.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_wheat.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_yam.nc',
#  'D:/ROSA/CROPGRIDSv1.08_NC_maps/CROPGRIDSv1.08_NC_maps\\CROPGRIDSv1.08_yautia.nc']

# %%
# Cargar el shapefile de hexágonos
hex_shapefile = "D:/ROSA/hex25.shp"
hexagons = gpd.read_file(hex_shapefile)

# %%
hexagons.columns
# Out:
# Index(['fid', 'H_ID', 'geometry'], dtype='object')

# %%
# Obtener la proyección del shapefil

shapefile_crs = hexagons.crs
shapefile_crs
# Out:
# <Derived Projected CRS: PROJCS["WGS_1984_Web_Mercator_Auxiliary_Sphere",GE ...>
# Name: WGS_1984_Web_Mercator_Auxiliary_Sphere
# Axis Info [cartesian]:
# - [east]: Easting (Meter)
# - [north]: Northing (Meter)
# Area of Use:
# - undefined
# Coordinate Operation:
# - name: unnamed
# - method: Popular Visualisation Pseudo Mercator
# Datum: World Geodetic System 1984
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
epsg_code = shapefile_crs.to_epsg()
if epsg_code:
    dst_crs = f"EPSG:{epsg_code}"
else:
    dst_crs = shapefile_crs.to_wkt()

# %%
# Inicializar un DataFrame de pandas para almacenar los resultados
results_df = pd.DataFrame()
results_df['H_ID'] = hexagons['H_ID']

# %%
hexagons.set_crs('epsg:3857', inplace=True, allow_override=True)
# Out:
#          fid  H_ID                                           geometry
# 0        1.0     1  MULTIPOLYGON (((-8987202.415 -469818.808, -898...
# 1        2.0     2  MULTIPOLYGON (((-8990913.062 -480981.695, -899...
# 2        3.0     3  MULTIPOLYGON (((-8976998.123 -451217.170, -897...
# 3        4.0     4  MULTIPOLYGON (((-8976189.941 -452560.999, -897...
# 4        5.0     5  MULTIPOLYGON (((-8965866.173 -427970.498, -896...
# ...      ...   ...                                                ...
# 5196  5197.0  5197  MULTIPOLYGON (((-7049557.421 -2207483.738, -70...
# 5197  5198.0  5198  MULTIPOLYGON (((-7044659.675 -2158861.454, -70...
# 5198  5199.0  5199  MULTIPOLYGON (((-7038113.750 -2313550.758, -70...
# 5199  5200.0  5200  MULTIPOLYGON (((-7037185.999 -2273817.539, -70...
# 5200  5201.0  5201  MULTIPOLYGON (((-7033527.716 -2213938.813, -70...
#
# [5201 rows x 3 columns]

# %%
# Iterar sobre cada archivo .nc
for idx, raster_file in enumerate(raster_files):
    raster = xr.open_dataset(raster_file, engine='netcdf4')

    raster = raster.rio.write_crs("epsg:4326", inplace=True)

    # Clip raster con la geometría del shapefile
    try:
        raster = raster.rio.clip(hexagons.geometry.apply(mapping),
 # This is needed if your GDF is in a diff CRS than the raster data
    hexagons.crs)
        
    except Exception as e:
        print(f"Error al recortar el raster {raster_file}: {e}")
        continue
    
    # Verificar si la variable 'croparea' existe en el dataset
    if 'croparea' in raster.data_vars:
        da = raster['croparea']
    else:
        print(f"'croparea' no encontrada en {raster_file}")
        continue  # Si no se encuentra la banda 'croparea', pasar al siguiente archivo



    # Filtrar los valores mayores a cero

    da = da.where(da > 0)
    print(da)
    arr = da.values
    
    # Calcular las estadísticas zonales
    affine = da.rio.transform()


    stats = zonal_stats(hexagons, arr, affine=affine, stats=['count'], nodata= np.nan)
    
    # Convertir las estadísticas a un DataFrame y agregar la columna del archivo
    stats_df = pd.DataFrame(stats)
    stats_df['file'] = raster_file
    
     # Agregar los resultados al DataFrame general
    all_stats_df = pd.concat([results_df, stats_df], ignore_index=True)
    
    # Guardar el DataFrame actualizado en un archivo CSV
    results_df.to_csv(output_csv, index=False)
    print(f"Resultados de {raster_file} guardados en {output_csv}")
# Out:
# c:\Users\Usuario\anaconda3\lib\site-packages\xarray\backends\plugins.py:71: RuntimeWarning: Engine 'cfgrib' loading failed:
# Cannot find the ecCodes library
#   warnings.warn(f"Engine {name!r} loading failed:\n{ex}", RuntimeWarning)
